# %%
import os
import pickle
import mediapipe as mp
import cv2

# %%
from mediapipe import solutions as mp_solutions
mp_hands = mp_solutions.hands
mp_drawing = mp_solutions.drawing_utils
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from mediapipe import solutions as mp_solutions
#       2 mp_hands = mp_solutions.hands
#       3 mp_drawing = mp_solutions.drawing_utils
#
# ImportError: cannot import name 'solutions' from 'mediapipe' (c:\Users\marcell asmoro\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\__init__.py)

# %%
with open('data.pickle', 'rb') as f:
    dataset = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open('data.pickle', 'rb') as f:
#       2     dataset = pickle.load(f)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.pickle'
